# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer as SI

# %%
data=pd.read_csv("chocolate_bars.csv")
df=pd.DataFrame(data)

# %%
df = pd.read_csv('chocolate_bars.csv')
df.head()
# Out:
#      id manufacturer company_location  year_reviewed         bean_origin  \
# 0  2454         5150           U.S.A.           2019            Tanzania
# 1  2458         5150           U.S.A.           2019  Dominican Republic
# 2  2454         5150           U.S.A.           2019          Madagascar
# 3  2542         5150           U.S.A.           2021                Fiji
# 4  2546         5150           U.S.A.           2021           Venezuela
#
#                  bar_name  cocoa_percent  num_ingredients ingredients  \
# 0   Kokoa Kamili, batch 1           76.0              3.0       B,S,C
# 1         Zorzal, batch 1           76.0              3.0       B,S,C
# 2  Bejofo Estate, batch 1           76.0              3.0       B,S,C
# 3   Matasawalevu, batch 1           68.0              3.0       B,S,C
# 4   Sur del Lago, batch 1           72.0              3.0       B,S,C
#
#                               review  rating
# 0          rich cocoa, fatty, bready    3.25
# ...

# %%
df.shape
# Out:
# (2530, 11)

# %%
df.describe()
# Out:
#                 id  year_reviewed  cocoa_percent  num_ingredients       rating
# count  2530.000000    2530.000000    2530.000000      2443.000000  2530.000000
# mean   1429.800791    2014.374308      71.639723         3.041343     3.196344
# std     757.648556       3.968267       5.616724         0.913728     0.445321
# min       5.000000    2006.000000      42.000000         1.000000     1.000000
# 25%     802.000000    2012.000000      70.000000         2.000000     3.000000
# 50%    1454.000000    2015.000000      70.000000         3.000000     3.250000
# 75%    2079.000000    2018.000000      74.000000         4.000000     3.500000
# max    2712.000000    2021.000000     100.000000         6.000000     4.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2530 entries, 0 to 2529
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                2530 non-null   int64
#  1   manufacturer      2530 non-null   object
#  2   company_location  2530 non-null   object
#  3   year_reviewed     2530 non-null   int64
#  4   bean_origin       2530 non-null   object
#  5   bar_name          2530 non-null   object
#  6   cocoa_percent     2530 non-null   float64
#  7   num_ingredients   2443 non-null   float64
#  8   ingredients       2443 non-null   object
#  9   review            2530 non-null   object
#  10  rating            2530 non-null   float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 217.5+ KB

# %% [markdown]
# # Checking the null values

# %%
df.isnull().sum()
# Out:
# id                   0
# manufacturer         0
# company_location     0
# year_reviewed        0
# bean_origin          0
# bar_name             0
# cocoa_percent        0
# num_ingredients     87
# ingredients         87
# review               0
# rating               0
# dtype: int64

# %% [markdown]
# # Replacing the null values with the Most_frequent values by using simple imputer

# %%
impute=SI(missing_values =np.nan,strategy ='most_frequent')
impute.fit(df)
df.iloc[:,7:9]=impute.fit_transform(df.iloc[:,7:9])

# %%
df.isnull().sum()
# Out:
# id                  0
# manufacturer        0
# company_location    0
# year_reviewed       0
# bean_origin         0
# bar_name            0
# cocoa_percent       0
# num_ingredients     0
# ingredients         0
# review              0
# rating              0
# dtype: int64

# %%
data.dtypes
# Out:
# id                    int64
# manufacturer         object
# company_location     object
# year_reviewed         int64
# bean_origin          object
# bar_name             object
# cocoa_percent       float64
# num_ingredients     float64
# ingredients          object
# review               object
# rating              float64
# dtype: object

# %% [markdown]
# # Unique function

# %%
df['rating'].unique()
# Out:
# array([3.25, 3.5 , 3.75, 3.  , 2.75, 4.  , 2.5 , 1.75, 2.25, 1.5 , 2.  ,
#        1.  ])

# %%
df['bean_origin'].unique()
# Out:
# array(['Tanzania', 'Dominican Republic', 'Madagascar', 'Fiji',
#        'Venezuela', 'Uganda', 'India', 'Bolivia', 'Peru', 'Panama',
#        'Colombia', 'Burma', 'Brazil', 'Papua New Guinea', 'Ecuador',
#        'Cuba', 'Togo', 'Sao Tome', 'Mexico', 'Vanuatu', 'Indonesia',
#        'Trinidad', 'Vietnam', 'Nicaragua', 'Ghana', 'Belize', 'Blend',
#        'Jamaica', 'Grenada', 'Guatemala', 'Honduras', 'Costa Rica',
#        'Haiti', 'Congo', 'Philippines', 'Solomon Islands', 'Malaysia',
#        'Sri Lanka', 'Ivory Coast', 'Gabon', 'Taiwan', 'Puerto Rico',
#        'Martinique', 'St. Lucia', 'Australia', 'Liberia', 'Sierra Leone',
#        'U.S.A.', 'Nigeria', 'St.Vincent-Grenadines', 'Thailand', 'Tobago',
#        'Sao Tome & Principe', 'Sumatra', 'El Salvador', 'Cameroon',
#        'Samoa', 'China', 'Principe', 'Sulawesi', 'Suriname', 'DR Congo'],
#       dtype=object)

# %%
df['company_location'].unique()
# Out:
# array(['U.S.A.', 'France', 'Fiji', 'Vanuatu', 'Ecuador', 'Mexico', 'U.K.',
#        'Netherlands', 'Spain', 'Russia', 'Peru', 'Canada', 'Italy',
#        'Brazil', 'Nicaragua', 'Australia', 'Philippines', 'Wales',
#        'Belgium', 'Vietnam', 'Germany', 'Singapore', 'Switzerland',
#        'Venezuela', 'Malaysia', 'South Korea', 'Taiwan', 'Puerto Rico',
#        'Colombia', 'Japan', 'New Zealand', 'Costa Rica', 'Hungary',
#        'Amsterdam', 'Scotland', 'Martinique', 'Sao Tome', 'St. Lucia',
#        'Argentina', 'Guatemala', 'South Africa', 'Dominican Republic',
#        'Sao Tome & Principe', 'Bolivia', 'Portugal', 'Norway', 'Denmark',
#        'Grenada', 'Israel', 'India', 'St.Vincent-Grenadines',
#        'Czech Republic', 'Thailand', 'Finland', 'Madagascar', 'Sweden',
#        'Poland', 'Austria', 'Honduras', 'U.A.E.', 'Lithuania', 'Ireland',
#        'Chile', 'Ghana', 'Iceland', 'Suriname', 'El Salvador'],
#       dtype=object)

# %%
df['bar_name'].unique()
# Out:
# array(['Kokoa Kamili, batch 1', 'Zorzal, batch 1',
#        'Bejofo Estate, batch 1', ..., 'APROCAFA, Acandi',
#        'Dry Aged, 30 yr Anniversary bar', 'Mountains of the Moon'],
#       dtype=object)

# %%
df['num_ingredients'].unique()
# Out:
# array([3., 4., 2., 5., 6., 1.])

# %%
df['ingredients'].unique()
# Out:
# array(['B,S,C', 'B,S,C,L', 'B,S', 'B,S,C,V', 'B,S,C,V,L', 'B,S,C,V,L,Sa',
#        'B,S,C,V,Sa', 'B,S,V,L', 'B,S*', 'B', 'B,S*,C', 'B,S,L', 'B,S,V',
#        'B,S*,C,L', 'B,S*,C,Sa', 'B,S*,Sa', 'B,S,C,Sa', 'B,S*,V,L', 'B,C',
#        'B,S*,C,V', 'B,S,C,L,Sa'], dtype=object)

# %%
df['review'].unique()
# Out:
# array(['rich cocoa, fatty, bready', 'cocoa, vegetal, savory',
#        'cocoa, blackberry, full body', ..., 'fatty, earthy, cocoa',
#        'fatty, mild nuts, mild fruit', 'muted, roasty, accessible'],
#       dtype=object)

# %%
df['cocoa_percent'].unique()
# Out:
# array([ 76. ,  68. ,  72. ,  80. ,  70. ,  63. ,  74. ,  60. ,  88. ,
#         55. ,  75. ,  65. ,  85. ,  73. ,  64. ,  66. ,  50. , 100. ,
#         77. ,  82. ,  90. ,  71. ,  83. ,  78. ,  86. ,  62. ,  69. ,
#         91. ,  67. ,  42. ,  61. ,  73.5,  79. ,  58. ,  71.5,  60.5,
#         81. ,  57. ,  72.5,  56. ,  46. ,  89. ,  99. ,  84. ,  53. ,
#         87. ])

# %%
for column in df.columns:
    print(column,":",df[column].nunique())
# Out:
# id : 630
# manufacturer : 580
# company_location : 67
# year_reviewed : 16
# bean_origin : 62
# bar_name : 1605
# cocoa_percent : 46
# num_ingredients : 6
# ingredients : 21
# review : 2487
# rating : 12

# %%
df.groupby('bean_origin').size().plot(kind='bar',figsize=(13,4))
plt.show()

# %%
df.groupby('company_location').size().plot(kind='bar',figsize=(13,4))
plt.show()

# %%
df.groupby('year_reviewed').sum()['rating'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='year_reviewed'>

# %%
df.groupby('ingredients').mean()['cocoa_percent'].plot(kind='bar')
plt.show()

# %%
df.groupby('ingredients').mean()['rating'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='ingredients'>

# %%
df.groupby('company_location').mean()['cocoa_percent'].plot(kind='bar',figsize=(13,4))
# Out:
# <AxesSubplot:xlabel='company_location'>

# %%
sns.set(rc={'figure.figsize':(15,6)})
sns.countplot(x='year_reviewed',hue='rating',data=df)
# Out:
# <AxesSubplot:xlabel='year_reviewed', ylabel='count'>

# %%
df.groupby('company_location').mean()['id'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='company_location'>

# %%
plt.plot(df.cocoa_percent)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(data.corr(), annot=True,cmap='viridis')
plt.show()

# %%
plt.plot(df['cocoa_percent'], marker='', label='Data Points')
plt.legend()
plt.show()

# %% [markdown]
# # Bean Origin of best rated chocolate bars

# %%
fig, ax = plt.subplots(figsize=[12,6])
sns.boxplot(data=df, y='rating', x='bean_origin',ax=ax)
plt.xticks(rotation = 90)
fig.tight_layout()

# %%
df_by_origin = df.groupby(by='bean_origin')['rating'].describe()
sort_by_median = df_by_origin.sort_values(by='50%', ascending=False)
sort_by_75perc = df_by_origin.sort_values(by='75%', ascending=False)

# %%
sort_by_median.reset_index().loc[:4,'bean_origin']
# Out:
# 0                 Tobago
# 1    Sao Tome & Principe
# 2               Thailand
# 3                  China
# 4                   Cuba
# Name: bean_origin, dtype: object

# %%
sort_by_75perc.reset_index().loc[:4,'bean_origin']
# Out:
# 0                 Tobago
# 1        Solomon Islands
# 2                   Cuba
# 3                Jamaica
# 4    Sao Tome & Principe
# Name: bean_origin, dtype: object

# %% [markdown]
# # Do cacao percentage or ingredients correlate with rating?

# %%
sns.pairplot(df)

# %%
sns.regplot(x="cocoa_percent", y="rating",data=df)
y = df["cocoa_percent"]
x = df["rating"]
correlation = y.corr(x)
print(correlation)
# Out:
# -0.07717329423244076

# %%
sns.regplot(x="id", y="rating", data=df)
y = df["id"]
x = df["rating"]
correlation = y.corr(x)
print(correlation)
# Out:
# 0.08556900560502559

# %%
sns.regplot(x="year_reviewed", y="rating", data=df)
y = df["year_reviewed"]
x = df["rating"]
correlation = y.corr(x)
print(correlation)
# Out:
# 0.08777413393472727

# %%
sns.regplot(x="num_ingredients", y="rating", data=df)
y = df["num_ingredients"]
x = df["rating"]
correlation = y.corr(x)
print(correlation)
# Out:
# -0.09883439748105384

# %% [markdown]
# # Which countries of bean origin results in the highest rating?

# %%
df.groupby('bean_origin').mean()['rating']
# Out:
# bean_origin
# Australia    3.250000
# Belize       3.233553
# Blend        3.038462
# Bolivia      3.181250
# Brazil       3.262821
#                ...
# U.S.A.       3.242424
# Uganda       3.065789
# Vanuatu      3.115385
# Venezuela    3.231225
# Vietnam      3.287671
# Name: rating, Length: 62, dtype: float64

# %%
plt.hist(df.groupby('bean_origin').mean()['rating'], bins=20, edgecolor='black')  # Plotting the histogram
plt.title("Bean Origin vs Rating",fontsize=14)
plt.xlabel("Ratings",fontsize=14)
plt.ylabel("Cacao persentage",fontsize=14)
plt.show()

# %%
plt.figure(figsize = (10,25))

sns.catplot(x = 'bean_origin',y = 'rating',kind = "bar",height = 10,aspect = 2,data = df.head(2530)).set(title = "Bean Origin vs Ratings");
plt.xticks(rotation = 90)
plt.xlabel("Bean Origin",fontsize=14)
plt.ylabel("Ratings",fontsize=14)

plt.show()

# %% [markdown]
# # Does cocoa percentage or ingredients affect the rating?

# %%
y = df["cocoa_percent"]
x = df["rating"]
correlation = y.corr(x)
print(correlation)

plt.figure(figsize = (25,10))
sns.regplot(x="cocoa_percent", y="rating", data=df)
plt.title("Bean Origin vs Rating",fontsize=14)
plt.xticks(rotation = 0)
plt.xlabel("Cacao persentage",fontsize=14)
plt.ylabel("Ratings",fontsize=14)
plt.show()
# Out:
# -0.07717329423244076

# %% [markdown]
# # With these high rates, what are the most memorable characteristics?

# %%
plt.figure(figsize = (25,10))

df.groupby('company_location').mean()['rating'].plot(kind='bar')

plt.xticks(rotation=90)
plt.xlabel("Company location",fontsize=14)
plt.ylabel("Rating'",fontsize=14)
plt.title("Company location versus rating",fontsize=14)

plt.show()

# %% [markdown]
# # Cocoa Percentage patterns over the year

# %%
dcoco = df.groupby('year_reviewed').aggregate({'cocoa_percent':'mean'})
dcoco = dcoco.reset_index()

# Plotting
sns.set()
plt.figure(figsize=(15, 4))
ax = sns.lineplot(x='year_reviewed', y='cocoa_percent', data=dcoco)
ax.set(xticks=dcoco.year_reviewed.values)
plt.xlabel("\nDate of Review")
plt.ylabel("Average Cocoa Percentage")
plt.title("Cocoa Percentage patterns over the years \n")
plt.show()

# %% [markdown]
# # Average Ratings over the year

# %%
df.groupby('year_reviewed').mean()['rating'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='year_reviewed'>

# %%
drate = df.groupby('year_reviewed').aggregate({'rating':'mean'})
drate = drate.reset_index()

# Plotting
sns.set()
plt.figure(figsize=(15, 4))
ax = sns.lineplot(x='year_reviewed', y='rating', data=drate)
ax.set(xticks=drate.year_reviewed.values)
plt.xlabel("\nDate of Review")
plt.ylabel("Average Rating")
plt.title("Average Rating over the years \n")
plt.show()

# %% [markdown]
# # Top 10 companies in terms of chocolate bars

# %%
d = df['company_location'].value_counts().sort_values(ascending=False).head(10)
d = pd.DataFrame(d)
d = d.reset_index() # dataframe with top 10 companies

# Plotting
sns.set()
plt.figure(figsize=(10,4))
sns.barplot(x='index', y='company_location', data=d)
plt.xlabel("\nChocolate Company")
plt.ylabel("Number of Bars")
plt.title("Top 5 Companies in terms of Chocolate Bars\n")
plt.show()

# %% [markdown]
# # Top 10 companies in terms of average ratings

# %%
d2 = df.groupby('company_location').aggregate({'rating':'mean'})
d2 = d2.sort_values('rating', ascending=False).head(10)
d2 = d2.reset_index()

# Plotting
sns.set()
plt.figure(figsize=(20, 6))
sns.barplot(x='company_location', y='rating', data=d2)
plt.xlabel("\nChocolate Company")
plt.ylabel("Average Rating")
plt.title("Top 10 Companies in terms of Average Ratings \n")
plt.show()

# %% [markdown]
# # Top 10 companies in terms of average ratings

# %%
top10_dict = {}
d = df['company_location'].value_counts().sort_values(ascending=False).head(10)
d = pd.DataFrame(d)
d = d.reset_index() # dataframe with top 10 companies
for element in list(d['index']):
    temp = df[df['company_location']==element]
    top10_dict[element]=temp

top10_list = list(top10_dict.keys())

# Rating over the years
d7 = df.groupby(['year_reviewed', 'company_location']).aggregate({'rating':'mean'})
d7 = d7.reset_index()
d7 = d7[d7['company_location'].isin(top10_list)]


# Plotting
sns.set()
plt.figure(figsize=(15, 4))
ax = sns.lineplot(x='year_reviewed', y='rating', hue="company_location", data=d7, palette="husl")
ax.set(xticks=d7.year_reviewed.values)
plt.xlabel("\nDate of Review")
plt.ylabel("Average Rating")
plt.title("Average Rating over the years (Top 10 Producer Companies)\n")
plt.show()

# %%
unsatisfactory = df[df['rating'] < 3.0]
satisfactory = df[(df['rating'] >= 3.0) & (df.rating < 4)]
pre_elite = df[df['rating'] >= 4.0]
label_names=['Unsatisfactory','Above Satisfactory','Premium']
sizes = [unsatisfactory.shape[0],satisfactory.shape[0],pre_elite.shape[0]]

# Making the donut plot
explode = (0.05,0.05,0.05)
my_circle=plt.Circle((0,0),0.7,color='white')
plt.figure(figsize=(7,7))
plt.pie(sizes,labels=label_names,explode=explode,autopct='%1.1f%%',pctdistance=0.85,startangle=90,shadow=True)
fig=plt.gcf()
fig.gca().add_artist(my_circle)
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
r=list(df['rating'].value_counts())
rating=df['rating'].value_counts().index.tolist()
rat=dict(zip(rating,r))
for key,val in rat.items():
    print ('Rating:',key,'Reviews:',val)
plt.figure(figsize=(10,5))
sns.countplot(x='rating',data=df)
plt.xlabel('Rating of chocolate bar',size=12,color='blue')
plt.ylabel('Number of Chocolate bars',size=12,color='blue')
plt.show()
# Out:
# Rating: 3.5 Reviews: 565
# Rating: 3.0 Reviews: 523
# Rating: 3.25 Reviews: 464
# Rating: 2.75 Reviews: 333
# Rating: 3.75 Reviews: 300
# Rating: 2.5 Reviews: 166
# Rating: 4.0 Reviews: 112
# Rating: 2.0 Reviews: 33
# Rating: 2.25 Reviews: 17
# Rating: 1.5 Reviews: 10
# Rating: 1.0 Reviews: 4
# Rating: 1.75 Reviews: 3

# %%
plt.figure(figsize=(10,5))
df['cocoa_percent'].value_counts().head(10).sort_index().plot.bar()
plt.xlabel('Percentage of Cocoa',size=12)
plt.ylabel('Number of Chocolate bars',size=12)
plt.show()

# %%
countries=df['bean_origin'].value_counts().index.tolist()[:5]
satisfactory={} 
for j in countries:
    c=0
    b=df[df['bean_origin']==j]
    br=b[b['rating']>=3] 
    for i in br['rating']:
        c+=1
        satisfactory[j]=c    

# Code to visualize the countries that give best cocoa beans
li=satisfactory.keys()
plt.figure(figsize=(10,5))
plt.bar(range(len(satisfactory)), satisfactory.values(), align='center',color=['#a22a2a','#511515','#e59a9a','#d04949','#a22a2a'])
plt.xticks(range(len(satisfactory)), list(li))
plt.xlabel('\nCountry')
plt.ylabel('Number of chocolate bars')
plt.title("Top 5 Broad origins of the Chocolate Beans with a Rating above 3.0\n")
plt.show()

print(satisfactory)
# Out:
# {'Venezuela': 199, 'Peru': 179, 'Dominican Republic': 182, 'Ecuador': 162, 'Madagascar': 147}

# %%
fig, ax = plt.subplots(figsize=(15, 5))
sns.barplot(x='num_ingredients', y='rating', data=df);
plt.xticks(rotation=90)
ax.bar_label(ax.containers[0])
plt.show()

# %% [markdown]
# # Multivarient Analysis

# %%
plt.close()
sns.set_style("whitegrid")
sns.pairplot(df,hue="cocoa_percent")
plt.show()

# %%
plt.close()
sns.set_style("whitegrid")
sns.pairplot(df,hue="id")
plt.show()
